# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetsar/challenges/blob/main/CovidTurkey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#         location  ... daily_vaccinations_per_million
# 0  #country+name  ...                            NaN
# 1    Afghanistan  ...                            NaN
# 2    Afghanistan  ...                           35.0
# 3    Afghanistan  ...                           35.0
# 4    Afghanistan  ...                           35.0
#
# [5 rows x 12 columns]

# %%
df.sample(15)
# Out:
#                      location  ... daily_vaccinations_per_million
# 6911                  Croatia  ...                         5144.0
# 31964               Venezuela  ...                         3662.0
# 20260                 Myanmar  ...                          225.0
# 17389              Low income  ...                           63.0
# 24808                  Rwanda  ...                          322.0
# 4163                 Botswana  ...                          351.0
# 2528                  Bahrain  ...                         4532.0
# 4083   Bosnia and Herzegovina  ...                         1507.0
# 10869                  Gambia  ...                            7.0
# 29892     Trinidad and Tobago  ...                         1866.0
# 9676           European Union  ...                         5241.0
# 572                   Algeria  ...                          517.0
# 31776              Uzbekistan  ...                         1192.0
# ...

# %%
dfTurk = df[df["location"]=="Turkey"]

# %%
dfTurk.head()
# Out:
#       location  ... daily_vaccinations_per_million
# 30080   Turkey  ...                            NaN
# 30081   Turkey  ...                         3313.0
# 30082   Turkey  ...                         3656.0
# 30083   Turkey  ...                         2675.0
# 30084   Turkey  ...                         2094.0
#
# [5 rows x 12 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dfTurk["year"]=dfTurk.date.dt.year
dfTurk["month"] = dfTurk.date.dt.strftime("%Y %m")

# %%
sns.barplot(x = dfTurk.month, y = dfTurk.total_vaccinations )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-62b220268d59> in <module>()
# ----> 1 sns.barplot(x = dfTurk.month, y = dfTurk.total_vaccinations )
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
# ...

# %%
dfTurk.head()
# Out:
#       location  ... daily_vaccinations_per_million
# 30080   Turkey  ...                            NaN
# 30081   Turkey  ...                         3313.0
# 30082   Turkey  ...                         3656.0
# 30083   Turkey  ...                         2675.0
# 30084   Turkey  ...                         2094.0
#
# [5 rows x 12 columns]

# %%
dfTurk.date.dt.
# Out:
#       location  ... daily_vaccinations_per_million
# 30080   Turkey  ...                            NaN
# 30081   Turkey  ...                         3313.0
# 30082   Turkey  ...                         3656.0
# 30083   Turkey  ...                         2675.0
# 30084   Turkey  ...                         2094.0
#
# [5 rows x 12 columns]
